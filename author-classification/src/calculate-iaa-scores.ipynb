# %% [markdown]
# # Calculate inter-annotator agreement for annotated data
#
# As we have a nominal scale with a multi-label classification problem,
# we should calculate Krippendorff's alpha (see [1]) to measure inter-annotator agreement.
#
# - α = 1 indicates perfect reliability.
# - α = 0 indicates the complete absence of reliability. Units and the values assigned to them are statistically unrelated.
# - α < 0 when disagreements are systematic and exceed what can be expected by chance. [2]
#
# The minimum acceptable α coefficient should be chosen according to the importance of the conclusions to be drawn from imperfect data. When the costs of mistaken conclusions are high, the minimum alpha needs to be set high as well. In the absence of knowledge of the risks of drawing false conclusions from unreliable data, social scientists commonly rely on data with reliabilities α ≥ 0.800, consider data with 0.800 > α ≥ 0.667 only to draw tentative conclusions, and discard data whose agreement measures α < 0.667. [3]
#
# [1] K. Krippendorff, “Reliability in Content Analysis: Some Common Misconceptions and Recommendations,” Human Communication Research, vol. 30, no. 3, pp. 411–433, Jul. 2004, doi: 10.1111/j.1468-2958.2004.tb00738.x.
# [2] https://en.wikipedia.org/wiki/Krippendorff%27s_alpha#General_form_of_alpha
# [3] https://en.wikipedia.org/wiki/Krippendorff%27s_alpha#Significance

# %%
import pandas as pd

# Attempt to load the data using UTF-16 encoding, which may resolve encoding issues
variables_df = pd.read_csv('../data/variables_res-soft-class_2024-10-31_21-58.csv', delimiter=';', encoding='utf-16')
data_df = pd.read_csv('../data/data_res-soft-class_2024-10-31_21-46.csv', delimiter=';', encoding='utf-16')
values_df = pd.read_csv('../data/values_res-soft-class_2024-10-31_21-58.csv', delimiter=';', encoding='utf-16')

# %% [markdown]
# First, build the matrix.

# %%
from csv import DictReader

item_col = "R004_01"
complete_col = "FINISHED"
annotator_col = "R003"
cat_cols = [
    "R001x01", "R001x11", "R001x12", "R001x13", 
    "R001x14", "R001x15", "R001x02", "R001x21", 
    "R001x22", "R001x23", "R001x03", "R001x31", 
    "R001x32", "R001x33", "R001x34", "R001x35", 
    "R001x36", "R001x37", "R001x38", "R001x99"
]

data = []

for (idx, row) in data_df.iterrows():
    if row.FINISHED:
        data.append(
            (
                row.R003,
                row.R004_01,
                frozenset([cat for cat in cat_cols if row.loc[cat] == 2])
            )
        )        

data
# Out:
# [(3, '10.21105/joss.07134', frozenset({'R001x01', 'R001x11'})),
#  (9, '10.21105/joss.07134', frozenset({'R001x01', 'R001x11'})),
#  (9,
#   '10.21105/joss.06914',
#   frozenset({'R001x01', 'R001x03', 'R001x12', 'R001x33', 'R001x36'})),
#  (2, '10.21105/joss.06914', frozenset({'R001x03', 'R001x32'})),
#  (2, '10.21105/joss.06825', frozenset({'R001x02'})),
#  (1, '10.21105/joss.06825', frozenset({'R001x02'})),
#  (1, '10.21105/joss.06642', frozenset({'R001x01', 'R001x12'})),
#  (1,
#   '10.21105/joss.05833',
#   frozenset({'R001x01', 'R001x03', 'R001x12', 'R001x32'})),
#  (3,
#   '10.21105/joss.06642',
#   frozenset({'R001x02', 'R001x03', 'R001x22', 'R001x36'})),
#  (1, '10.21105/joss.06932', frozenset({'R001x01', 'R001x11'})),
#  (1, '10.21105/joss.07031', frozenset({'R001x01', 'R001x12'})),
#  (12, '10.21105/joss.07031', frozenset({'R001x01', 'R001x12'})),
#  (12, '10.21105/joss.05833', frozenset({'R001x01', 'R001x12'})),
#  (12, '10.21105/joss.06932', frozenset({'R001x03', 'R001x32'})),
#  (3, '10.21105/joss.05766', frozenset({'R001x01', 'R001x11', 'R001x12'})),
#  (1, '10.21105/joss.05766', frozenset({'R001x01', 'R001x12'})),
#  (12, '10.21105/joss.03358', frozenset({'R001x03', 'R001x31', 'R001x33'})),
#  (12, '10.21105/joss.06766', frozenset({'R001x01', 'R001x11'})),
#  (12,
#   '10.21105/joss.03877',
#   frozenset({'R001x01', 'R001x03', 'R001x11', 'R001x33'})),
#  (1, '10.21105/joss.06766', frozenset({'R001x01', 'R001x11'})),
#  (1, '10.21105/joss.03358', frozenset({'R001x03', 'R001x32'})),
#  (1, '10.21105/joss.03877', frozenset({'R001x03', 'R001x33'})),
#  (1, '10.21105/joss.05744', frozenset({'R001x01', 'R001x11'})),
#  (1, '10.21105/joss.04591', frozenset({'R001x02', 'R001x22'})),
#  (1, '10.21105/joss.04958', frozenset({'R001x01', 'R001x11'})),
#  (1, '10.21105/joss.04354', frozenset({'R001x01', 'R001x12'})),
#  (1, '10.21105/joss.06210', frozenset({'R001x01', 'R001x12'})),
#  (1, '10.21105/joss.06451', frozenset({'R001x01', 'R001x11'})),
#  (1, '10.21105/joss.02334', frozenset({'R001x03', 'R001x33'})),
#  (1, '10.21105/joss.02116', frozenset({'R001x01', 'R001x12'})),
#  (1, '10.21105/joss.02809', frozenset({'R001x01', 'R001x11'})),
#  (1, '10.21105/joss.05959', frozenset({'R001x01', 'R001x11'})),
#  (1, '10.21105/joss.04070', frozenset({'R001x01', 'R001x11'})),
#  (1, '10.21105/joss.05206', frozenset({'R001x01', 'R001x12'})),
#  (1, '10.21105/joss.05375', frozenset({'R001x01', 'R001x12'})),
#  (1, '10.21105/joss.03344', frozenset({'R001x01', 'R001x11'})),
#  (1, '10.21105/joss.04989', frozenset({'R001x01', 'R001x12'})),
#  (1, '10.21105/joss.02805', frozenset({'R001x01', 'R001x12', 'R001x15'})),
#  (1, '10.21105/joss.05573', frozenset({'R001x01', 'R001x11'})),
#  (10, '10.21105/joss.05375', frozenset({'R001x01', 'R001x12', 'R001x15'})),
#  (13, '10.21105/joss.06451', frozenset({'R001x03', 'R001x32'})),
#  (13, '10.21105/joss.05959', frozenset({'R001x01', 'R001x11'})),
#  (1, '10.21105/joss.03272', frozenset({'R001x03', 'R001x32'})),
#  (1, '10.21105/joss.04708', frozenset({'R001x02', 'R001x22'})),
#  (1, '10.21105/joss.02863', frozenset({'R001x03', 'R001x32'})),
#  (1, '10.21105/joss.03424', frozenset({'R001x01', 'R001x11'})),
#  (1, '10.21105/joss.06503', frozenset({'R001x01', 'R001x11'})),
#  (1, '10.21105/joss.01493', frozenset({'R001x03', 'R001x34'})),
#  (1, '10.21105/joss.02653', frozenset({'R001x01', 'R001x12'})),
#  (13, '10.21105/joss.06503', frozenset({'R001x01', 'R001x11'})),
#  (1,
#   '10.21105/joss.05570',
#   frozenset({'R001x01', 'R001x03', 'R001x11', 'R001x34'})),
#  (1, '10.21105/joss.05100', frozenset({'R001x01', 'R001x11'})),
#  (1, '10.21105/joss.03895', frozenset({'R001x03', 'R001x33'})),
#  (1, '10.21105/joss.05236', frozenset({'R001x02', 'R001x22'})),
#  (1, '10.21105/joss.05268', frozenset({'R001x01', 'R001x12'})),
#  (1, '10.21105/joss.05202', frozenset({'R001x01', 'R001x11'})),
#  (1, '10.21105/joss.05844', frozenset({'R001x01', 'R001x12'})),
#  (1, '10.21105/joss.05887', frozenset({'R001x01', 'R001x12', 'R001x15'})),
#  (1, '10.21105/joss.06264', frozenset({'R001x01', 'R001x11'})),
#  (1, '10.21105/joss.02864', frozenset({'R001x01', 'R001x12'})),
#  (1, '10.21105/joss.03428', frozenset({'R001x01', 'R001x11'})),
#  (1, '10.21105/joss.01904', frozenset({'R001x02', 'R001x22'})),
#  (13, '10.21105/joss.01904', frozenset({'R001x01', 'R001x13'})),
#  (13,
#   '10.21105/joss.05236',
#   frozenset({'R001x01', 'R001x03', 'R001x11', 'R001x34'})),
#  (2, '10.21105/joss.02809', frozenset({'R001x01', 'R001x11'})),
#  (2,
#   '10.21105/joss.02805',
#   frozenset({'R001x01', 'R001x02', 'R001x11', 'R001x12', 'R001x22'})),
#  (1, '10.21105/joss.06940', frozenset({'R001x01', 'R001x11'})),
#  (2,
#   '10.21105/joss.04591',
#   frozenset({'R001x02', 'R001x03', 'R001x21', 'R001x33'})),
#  (2,
#   '10.21105/joss.02334',
#   frozenset({'R001x01', 'R001x03', 'R001x12', 'R001x31'})),
#  (2,
#   '10.21105/joss.02116',
#   frozenset({'R001x01',
#              'R001x03',
#              'R001x12',
#              'R001x15',
#              'R001x32',
#              'R001x33'})),
#  (2, '10.21105/joss.05202', frozenset({'R001x01', 'R001x11'})),
#  (2, '10.21105/joss.04708', frozenset({'R001x02', 'R001x22'})),
#  (2,
#   '10.21105/joss.03895',
#   frozenset({'R001x02', 'R001x03', 'R001x22', 'R001x33'})),
#  (1, '10.21105/joss.05402', frozenset({'R001x03', 'R001x32'})),
#  (1, '10.21105/joss.04868', frozenset({'R001x01', 'R001x11'})),
#  (1, '10.21105/joss.03609', frozenset({'R001x01', 'R001x12'})),
#  (1, '10.21105/joss.05201', frozenset({'R001x01', 'R001x12'})),
#  (3, '10.21105/joss.03272', frozenset({'R001x03', 'R001x32'})),
#  (3, '10.21105/joss.05887', frozenset({'R001x01', 'R001x12', 'R001x15'})),
#  (3, '10.21105/joss.03344', frozenset({'R001x03', 'R001x33', 'R001x34'})),
#  (1, '10.21105/joss.02011', frozenset({'R001x01', 'R001x11'})),
#  (3, '10.21105/joss.02011', frozenset({'R001x01', 'R001x11', 'R001x12'})),
#  (3, '10.21105/joss.02863', frozenset({'R001x03', 'R001x32'})),
#  (3, '10.21105/joss.05268', frozenset({'R001x01', 'R001x12'})),
#  (1, '10.21105/joss.05791', frozenset({'R001x01', 'R001x12'})),
#  (1, '10.21105/joss.02646', frozenset({'R001x02', 'R001x21'})),
#  (1, '10.21105/joss.04360', frozenset({'R001x01', 'R001x12'})),
#  (1,
#   '10.21105/joss.03284',
#   frozenset({'R001x03', 'R001x31', 'R001x32', 'R001x36'})),
#  (13, '10.21105/joss.04360', frozenset({'R001x01', 'R001x12'})),
#  (13, '10.21105/joss.01493', frozenset({'R001x03', 'R001x34'})),
#  (13, '10.21105/joss.05402', frozenset({'R001x01', 'R001x12'})),
#  (13, '10.21105/joss.05206', frozenset({'R001x01', 'R001x12'})),
#  (13,
#   '10.21105/joss.03284',
#   frozenset({'R001x01', 'R001x03', 'R001x12', 'R001x34'})),
#  (13, '10.21105/joss.05573', frozenset({'R001x03', 'R001x32', 'R001x34'})),
#  (13, '10.21105/joss.04958', frozenset({'R001x03', 'R001x34'})),
#  (13, '10.21105/joss.04354', frozenset({'R001x01', 'R001x12', 'R001x15'})),
#  (13, '10.21105/joss.06264', frozenset({'R001x01', 'R001x11'})),
#  (13, '10.21105/joss.06210', frozenset({'R001x03', 'R001x34'})),
#  (13, '10.21105/joss.04989', frozenset({'R001x01', 'R001x12'})),
#  (13, '10.21105/joss.03428', frozenset({'R001x01', 'R001x11'})),
#  (13, '10.21105/joss.05744', frozenset({'R001x01', 'R001x12'})),
#  (13, '10.21105/joss.05791', frozenset({'R001x01', 'R001x12'})),
#  (13, '10.21105/joss.05100', frozenset({'R001x01', 'R001x11'})),
#  (13, '10.21105/joss.02646', frozenset({'R001x03', 'R001x34'})),
#  (13, '10.21105/joss.02864', frozenset({'R001x01', 'R001x12'})),
#  (1, '10.21105/joss.06158', frozenset({'R001x01', 'R001x11'})),
#  (1, '10.21105/joss.06574', frozenset({'R001x03', 'R001x33'})),
#  (1, '10.21105/joss.02372', frozenset({'R001x01', 'R001x11'})),
#  (1, '10.21105/joss.02260', frozenset({'R001x03', 'R001x34'})),
#  (1, '10.21105/joss.06067', frozenset({'R001x03', 'R001x34'})),
#  (1,
#   '10.21105/joss.04564',
#   frozenset({'R001x01', 'R001x03', 'R001x12', 'R001x34'})),
#  (13, '10.21105/joss.06940', frozenset({'R001x01', 'R001x11'})),
#  (13, '10.21105/joss.03424', frozenset({'R001x01', 'R001x11'})),
#  (13, '10.21105/joss.06574', frozenset({'R001x01', 'R001x12'})),
#  (13, '10.21105/joss.03609', frozenset({'R001x01', 'R001x12'})),
#  (13, '10.21105/joss.02372', frozenset({'R001x03', 'R001x32'})),
#  (13,
#   '10.21105/joss.02260',
#   frozenset({'R001x01', 'R001x03', 'R001x12', 'R001x34'})),
#  (13,
#   '10.21105/joss.04868',
#   frozenset({'R001x01', 'R001x03', 'R001x15', 'R001x34'})),
#  (13, '10.21105/joss.02653', frozenset({'R001x01', 'R001x11'})),
#  (13, '10.21105/joss.04070', frozenset({'R001x01', 'R001x11'})),
#  (13, '10.21105/joss.05201', frozenset({'R001x01', 'R001x12'})),
#  (1, '10.21105/joss.04211', frozenset({'R001x01', 'R001x11'})),
#  (1, '10.21105/joss.06194', frozenset({'R001x01', 'R001x11'})),
#  (13, '10.21105/joss.06067', frozenset({'R001x03', 'R001x32', 'R001x34'})),
#  (13, '10.21105/joss.06158', frozenset({'R001x01', 'R001x11'})),
#  (1,
#   '10.21105/joss.06617',
#   frozenset({'R001x01', 'R001x03', 'R001x11', 'R001x34'})),
#  (1, '10.21105/joss.03032', frozenset({'R001x03', 'R001x32'})),
#  (1, '10.21105/joss.02817', frozenset({'R001x01', 'R001x12'})),
#  (1, '10.21105/joss.06170', frozenset({'R001x01', 'R001x11'})),
#  (1,
#   '10.21105/joss.03297',
#   frozenset({'R001x02', 'R001x03', 'R001x22', 'R001x33'})),
#  (1, '10.21105/joss.02175', frozenset({'R001x01', 'R001x12'})),
#  (1, '10.21105/joss.01956', frozenset({'R001x03', 'R001x33'})),
#  (1, '10.21105/joss.02369', frozenset({'R001x01', 'R001x11'})),
#  (1, '10.21105/joss.04924', frozenset({'R001x02', 'R001x21', 'R001x22'})),
#  (1, '10.21105/joss.06481', frozenset({'R001x01', 'R001x12'})),
#  (1,
#   '10.21105/joss.01746',
#   frozenset({'R001x02', 'R001x03', 'R001x22', 'R001x34'})),
#  (1, '10.21105/joss.02185', frozenset({'R001x01', 'R001x11'})),
#  (1, '10.21105/joss.05098', frozenset({'R001x01', 'R001x12'})),
#  (1, '10.21105/joss.06356', frozenset({'R001x01', 'R001x11'})),
#  (1, '10.21105/joss.02673', frozenset({'R001x03', 'R001x37'})),
#  (1, '10.21105/joss.03439', frozenset({'R001x01', 'R001x11'})),
#  (1, '10.21105/joss.02343', frozenset({'R001x01', 'R001x12'})),
#  (1, '10.21105/joss.01992', frozenset({'R001x01', 'R001x11'})),
#  (1, '10.21105/joss.04642', frozenset({'R001x03', 'R001x34'})),
#  (1, '10.21105/joss.02120', frozenset({'R001x01', 'R001x11'})),
#  (1, '10.21105/joss.06200', frozenset({'R001x01', 'R001x11'})),
#  (13, '10.21105/joss.02369', frozenset({'R001x03', 'R001x34'})),
#  (13, '10.21105/joss.02185', frozenset({'R001x03', 'R001x34'})),
#  (13, '10.21105/joss.04211', frozenset({'R001x01', 'R001x11'})),
#  (13, '10.21105/joss.01992', frozenset({'R001x03', 'R001x34'})),
#  (13, '10.21105/joss.02175', frozenset({'R001x03', 'R001x33'})),
#  (13, '10.21105/joss.04924', frozenset({'R001x01', 'R001x12'})),
#  (13, '10.21105/joss.03439', frozenset({'R001x01', 'R001x14'})),
#  (13, '10.21105/joss.01956', frozenset({'R001x03', 'R001x34'})),
#  (13, '10.21105/joss.06200', frozenset({'R001x01', 'R001x11'})),
#  (13, '10.21105/joss.03032', frozenset({'R001x03', 'R001x32'})),
#  (1, '10.21105/joss.03444', frozenset({'R001x01', 'R001x11'})),
#  (1, '10.21105/joss.03210', frozenset({'R001x01', 'R001x11'})),
#  (1, '10.21105/joss.05594', frozenset({'R001x01', 'R001x11'})),
#  (1,
#   '10.21105/joss.05619',
#   frozenset({'R001x01', 'R001x03', 'R001x12', 'R001x32'})),
#  (1, '10.21105/joss.02762', frozenset({'R001x01', 'R001x11'})),
#  (1,
#   '10.21105/joss.05605',
#   frozenset({'R001x01', 'R001x03', 'R001x12', 'R001x33'})),
#  (13, '10.21105/joss.02762', frozenset({'R001x01', 'R001x12'})),
#  (1, '10.21105/joss.03337', frozenset({'R001x03', 'R001x33'})),
#  (13, '10.21105/joss.03210', frozenset({'R001x02', 'R001x22'})),
#  (6, '10.21105/joss.06356', frozenset({'R001x01', 'R001x11'})),
#  (6, '10.21105/joss.06194', frozenset({'R001x01', 'R001x11'})),
#  (6, '10.21105/joss.05570', frozenset({'R001x01', 'R001x11'})),
#  (6,
#   '10.21105/joss.06170',
#   frozenset({'R001x01', 'R001x03', 'R001x11', 'R001x33'})),
#  (6, '10.21105/joss.05844', frozenset({'R001x03', 'R001x36'})),
#  (6, '10.21105/joss.01746', frozenset({'R001x03', 'R001x33'})),
#  (13, '10.21105/joss.01746', frozenset({'R001x02', 'R001x22'})),
#  (13, '10.21105/joss.06617', frozenset({'R001x03', 'R001x37'})),
#  (13, '10.21105/joss.02817', frozenset({'R001x03', 'R001x32'})),
#  (13, '10.21105/joss.06481', frozenset({'R001x02', 'R001x22'})),
#  (13, '10.21105/joss.02673', frozenset({'R001x03', 'R001x37'})),
#  (13, '10.21105/joss.03297', frozenset({'R001x03', 'R001x37'})),
#  (13, '10.21105/joss.04564', frozenset({'R001x01', 'R001x12'})),
#  (13, '10.21105/joss.02343', frozenset({'R001x01', 'R001x11', 'R001x12'})),
#  (1,
#   '10.21105/joss.04336',
#   frozenset({'R001x01', 'R001x03', 'R001x12', 'R001x15', 'R001x33'})),
#  (13,
#   '10.21105/joss.05098',
#   frozenset({'R001x01', 'R001x02', 'R001x12', 'R001x22'})),
#  (13, '10.21105/joss.05594', frozenset({'R001x01', 'R001x11'})),
#  (13, '10.21105/joss.05605', frozenset({'R001x01', 'R001x12'})),
#  (13, '10.21105/joss.04642', frozenset({'R001x02', 'R001x22'})),
#  (13, '10.21105/joss.02120', frozenset({'R001x01', 'R001x11'})),
#  (13, '10.21105/joss.03444', frozenset({'R001x01', 'R001x11'})),
#  (13, '10.21105/joss.03337', frozenset({'R001x03', 'R001x36'})),
#  (13, '10.21105/joss.04336', frozenset({'R001x01', 'R001x12'})),
#  (13, '10.21105/joss.05619', frozenset({'R001x02', 'R001x22'})),
#  (13, '10.21105/joss.02978', frozenset({'R001x02', 'R001x22'})),
#  (13, '10.21105/joss.03078', frozenset({'R001x03', 'R001x34'})),
#  (1, '10.21105/joss.02978', frozenset({'R001x01', 'R001x11'})),
#  (1, '10.21105/joss.03625', frozenset({'R001x01', 'R001x11'})),
#  (1,
#   '10.21105/joss.06032',
#   frozenset({'R001x01', 'R001x03', 'R001x12', 'R001x33', 'R001x34'})),
#  (1, '10.21105/joss.06433', frozenset({'R001x01', 'R001x11'})),
#  (1,
#   '10.21105/joss.04183',
#   frozenset({'R001x01', 'R001x02', 'R001x12', 'R001x22'})),
#  (1,
#   '10.21105/joss.04677',
#   frozenset({'R001x01', 'R001x03', 'R001x12', 'R001x33'})),
#  (1, '10.21105/joss.05453', frozenset({'R001x02', 'R001x22'})),
#  (13,
#   '10.21105/joss.04677',
#   frozenset({'R001x01', 'R001x03', 'R001x12', 'R001x33'})),
#  (13, '10.21105/joss.05453', frozenset({'R001x01', 'R001x11'})),
#  (6, '10.21105/joss.05453', frozenset({'R001x01', 'R001x12'})),
#  (13, '10.21105/joss.06433', frozenset({'R001x01', 'R001x11'})),
#  (6,
#   '10.21105/joss.03625',
#   frozenset({'R001x01', 'R001x03', 'R001x11', 'R001x32'})),
#  (13,
#   '10.21105/joss.03625',
#   frozenset({'R001x01', 'R001x03', 'R001x11', 'R001x36'})),
#  (6, '10.21105/joss.06032', frozenset({'R001x03', 'R001x33'})),
#  (13, '10.21105/joss.04183', frozenset({'R001x02', 'R001x22'})),
#  (6, '10.21105/joss.04183', frozenset({'R001x02', 'R001x22'})),
#  (13, '10.21105/joss.04898', frozenset({'R001x03', 'R001x36'})),
#  (6, '10.21105/joss.03078', frozenset({'R001x03', 'R001x34'})),
#  (6, '10.21105/joss.01981', frozenset({'R001x01', 'R001x12'})),
#  (6, '10.21105/joss.06899', frozenset({'R001x03', 'R001x34'})),
#  (13, '10.21105/joss.01981', frozenset({'R001x01', 'R001x12'})),
#  (6, '10.21105/joss.04898', frozenset({'R001x01', 'R001x12'})),
#  (6,
#   '10.21105/joss.04953',
#   frozenset({'R001x02', 'R001x03', 'R001x22', 'R001x33'})),
#  (6, '10.21105/joss.04278', frozenset({'R001x03', 'R001x34'})),
#  (6, '10.21105/joss.05496', frozenset({'R001x03', 'R001x34'})),
#  (6,
#   '10.21105/joss.03790',
#   frozenset({'R001x01', 'R001x03', 'R001x12', 'R001x34'})),
#  (6, '10.21105/joss.04099', frozenset({'R001x02', 'R001x22', 'R001x99'})),
#  (13, '10.21105/joss.03790', frozenset({'R001x02', 'R001x22'})),
#  (13, '10.21105/joss.06899', frozenset({'R001x01', 'R001x11'})),
#  (13, '10.21105/joss.05496', frozenset({'R001x02', 'R001x22'})),
#  (13, '10.21105/joss.04953', frozenset({'R001x03', 'R001x33', 'R001x37'})),
#  (13, '10.21105/joss.04278', frozenset({'R001x02', 'R001x22'})),
#  (13, '10.21105/joss.04099', frozenset({'R001x02', 'R001x22'})),
#  (13, '10.21105/joss.02862', frozenset({'R001x02', 'R001x22'})),
#  (1, '10.21105/joss.02862', frozenset({'R001x01', 'R001x12'})),
#  (1, '10.21105/joss.06203', frozenset({'R001x01', 'R001x11'})),
#  (1, '10.21105/joss.06358', frozenset({'R001x01', 'R001x11'})),
#  (1, '10.21105/joss.05855', frozenset({'R001x01', 'R001x11'})),
#  (1, '10.21105/joss.02017', frozenset({'R001x01', 'R001x15'})),
#  (1, '10.21105/joss.05940', frozenset({'R001x01', 'R001x12', 'R001x15'})),
#  (5,
#   '10.21105/joss.06203',
#   frozenset({'R001x01',
#              'R001x02',
#              'R001x03',
#              'R001x12',
#              'R001x22',
#              'R001x34'})),
#  (5,
#   '10.21105/joss.06358',
#   frozenset({'R001x01',
#              'R001x02',
#              'R001x03',
#              'R001x11',
#              'R001x22',
#              'R001x34'})),
#  (5,
#   '10.21105/joss.05855',
#   frozenset({'R001x01',
#              'R001x02',
#              'R001x03',
#              'R001x11',
#              'R001x22',
#              'R001x32'})),
#  (13, '10.21105/joss.05940', frozenset({'R001x01', 'R001x12'})),
#  (5,
#   '10.21105/joss.02017',
#   frozenset({'R001x01',
#              'R001x02',
#              'R001x03',
#              'R001x12',
#              'R001x22',
#              'R001x34'})),
#  (5,
#   '10.21105/joss.05940',
#   frozenset({'R001x01',
#              'R001x02',
#              'R001x03',
#              'R001x11',
#              'R001x12',
#              'R001x13',
#              'R001x14',
#              'R001x15',
#              'R001x22',
#              'R001x34'})),
#  (5, '10.21105/joss.02825', frozenset({'R001x01', 'R001x11', 'R001x15'})),
#  (13, '10.21105/joss.02825', frozenset({'R001x01', 'R001x11'})),
#  (13, '10.21105/joss.03465', frozenset({'R001x02', 'R001x22'})),
#  (13, '10.21105/joss.03097', frozenset({'R001x01', 'R001x11'})),
#  (1, '10.21105/joss.03097', frozenset({'R001x01', 'R001x11'})),
#  (1,
#   '10.21105/joss.03465',
#   frozenset({'R001x01', 'R001x03', 'R001x11', 'R001x34'}))]

# %% [markdown]
# Now, run two annotation tasks for measuring Krippendorff's alpha based on multi-label set distances, using Jacccard distance [1] and MASI distance [2].
#
# [1] P. Jaccard, Nouvelles recherches sur la distribution florale. Lausanne: Rouge, 1908.
# [2] R. Passonneau, “Measuring Agreement on Set-valued Items (MASI) for Semantic and Pragmatic Annotation,” in Proceedings of the Fifth International Conference on Language Resources and Evaluation (LREC’06), N. Calzolari, K. Choukri, A. Gangemi, B. Maegaard, J. Mariani, J. Odijk, and D. Tapias, Eds., Genoa, Italy: European Language Resources Association (ELRA), May 2006. Accessed: Nov. 06, 2024. [Online]. Available: http://www.lrec-conf.org/proceedings/lrec2006/pdf/636_pdf.pdf

'10.21105/joss.05605', '10.21105/joss.03358', '10.21105/joss.02175', '10.21105/joss.05766', '10.21105/joss.02185', '10.21105/joss.02372', '10.21105/joss.02673', '10.21105/joss.03465', '10.21105/joss.05844', '10.21105/joss.05594', '10.21105/joss.04211', '10.21105/joss.02116', '10.21105/joss.03284', '10.21105/joss.06503', '10.21105/joss.03790', '10.21105/joss.05833', '10.21105/joss.05268', '10.21105/joss.06642', '10.21105/joss.02863', '10.21105/joss.06210', '10.21105/joss.03078', '10.21105/joss.03272', '10.21105/joss.04642', '10.21105/joss.06264', '10.21105/joss.05791', '10.21105/joss.02260', '10.21105/joss.05959', '10.21105/joss.05236', '10.21105/joss.03625', '10.21105/joss.04868', '10.21105/joss.03609', '10.21105/joss.01904', '10.21105/joss.05744', '10.21105/joss.06032'}
# Annotations: {frozenset({'R001x02', 'R001x21'}), frozenset({'R001x03', 'R001x37'}), frozenset({'R001x32', 'R001x03'}), frozenset({'R001x34', 'R001x03', 'R001x33'}), frozenset({'R001x22', 'R001x01', 'R001x02', 'R001x14', 'R001x11', 'R001x15', 'R001x12', 'R001x34', 'R001x13', 'R001x03'}), frozenset({'R001x11', 'R001x01', 'R001x15'}), frozenset({'R001x03', 'R001x22', 'R001x36', 'R001x02'}), frozenset({'R001x01', 'R001x13'}), frozenset({'R001x01', 'R001x12', 'R001x33', 'R001x34', 'R001x03'}), frozenset({'R001x22', 'R001x01', 'R001x02', 'R001x11', 'R001x12'}), frozenset({'R001x22', 'R001x01', 'R001x02', 'R001x12'}), frozenset({'R001x14', 'R001x01'}), frozenset({'R001x11', 'R001x01', 'R001x03', 'R001x33'}), frozenset({'R001x34', 'R001x03'}), frozenset({'R001x11', 'R001x01', 'R001x12'}), frozenset({'R001x11', 'R001x01', 'R001x36', 'R001x03'}), frozenset({'R001x03', 'R001x33', 'R001x02', 'R001x21'}), frozenset({'R001x01', 'R001x15'}), frozenset({'R001x11', 'R001x01'}), frozenset({'R001x02'}), frozenset({'R001x32', 'R001x36', 'R001x31', 'R001x03'}), frozenset({'R001x03', 'R001x01', 'R001x12', 'R001x33'}), frozenset({'R001x01', 'R001x32', 'R001x15', 'R001x12', 'R001x33', 'R001x03'}), frozenset({'R001x03', 'R001x01', 'R001x31', 'R001x12'}), frozenset({'R001x03', 'R001x22', 'R001x34', 'R001x02'}), frozenset({'R001x32', 'R001x03', 'R001x01', 'R001x12'}), frozenset({'R001x01', 'R001x36', 'R001x12', 'R001x33', 'R001x03'}), frozenset({'R001x01', 'R001x15', 'R001x12'}), frozenset({'R001x22', 'R001x01', 'R001x02', 'R001x12', 'R001x34', 'R001x03'}), frozenset({'R001x03', 'R001x22', 'R001x02', 'R001x33'}), frozenset({'R001x01', 'R001x15', 'R001x12', 'R001x33', 'R001x03'}), frozenset({'R001x22', 'R001x02', 'R001x21'}), frozenset({'R001x03', 'R001x33'}), frozenset({'R001x32', 'R001x34', 'R001x03'}), frozenset({'R001x01', 'R001x12'}), frozenset({'R001x32', 'R001x11', 'R001x01', 'R001x03'}), frozenset({'R001x22', 'R001x01', 'R001x02', 'R001x11', 'R001x34', 'R001x03'}), frozenset({'R001x22', 'R001x02'}), frozenset({'R001x22', 'R001x02', 'R001x99'}), frozenset({'R001x31', 'R001x03', 'R001x33'}), frozenset({'R001x36', 'R001x03'}), frozenset({'R001x37', 'R001x03', 'R001x33'}), frozenset({'R001x34', 'R001x11', 'R001x01', 'R001x03'}), frozenset({'R001x22', 'R001x01', 'R001x02', 'R001
# Annotations: {frozenset({'R001x02', 'R001x21'}), frozenset({'R001x03', 'R001x37'}), frozenset({'R001x32', 'R001x03'}), frozenset({'R001x34', 'R001x03', 'R001x33'}), frozenset({'R001x22', 'R001x01', 'R001x02', 'R001x14', 'R001x11', 'R001x15', 'R001x12', 'R001x34', 'R001x13', 'R001x03'}), frozenset({'R001x11', 'R001x01', 'R001x15'}), frozenset({'R001x03', 'R001x22', 'R001x36', 'R001x02'}), frozenset({'R001x01', 'R001x13'}), frozenset({'R001x01', 'R001x12', 'R001x33', 'R001x34', 'R001x03'}), frozenset({'R001x22', 'R001x01', 'R001x02', 'R001x11', 'R001x12'}), frozenset({'R001x22', 'R001x01', 'R001x02', 'R001x12'}), frozenset({'R001x14', 'R001x01'}), frozenset({'R001x11', 'R001x01', 'R001x03', 'R001x33'}), frozenset({'R001x34', 'R001x03'}), frozenset({'R001x11', 'R001x01', 'R001x12'}), frozenset({'R001x11', 'R001x01', 'R001x36', 'R001x03'}), frozenset({'R001x03', 'R001x33', 'R001x02', 'R001x21'}), frozenset({'R001x01', 'R001x15'}), frozenset({'R001x11', 'R001x01'}), frozenset({'R001x02'}), frozenset({'R001x32', 'R001x36', 'R001x31', 'R001x03'}), frozenset({'R001x03', 'R001x01', 'R001x12', 'R001x33'}), frozenset({'R001x01', 'R001x32', 'R001x15', 'R001x12', 'R001x33', 'R001x03'}), frozenset({'R001x03', 'R001x01', 'R001x31', 'R001x12'}), frozenset({'R001x03', 'R001x22', 'R001x34', 'R001x02'}), frozenset({'R001x32', 'R001x03', 'R001x01', 'R001x12'}), frozenset({'R001x01', 'R001x36', 'R001x12', 'R001x33', 'R001x03'}), frozenset({'R001x01', 'R001x15', 'R001x12'}), frozenset({'R001x22', 'R001x01', 'R001x02', 'R001x12', 'R001x34', 'R001x03'}), frozenset({'R001x03', 'R001x22', 'R001x02', 'R001x33'}), frozenset({'R001x01', 'R001x15', 'R001x12', 'R001x33', 'R001x03'}), frozenset({'R001x22', 'R001x02', 'R001x21'}), frozenset({'R001x03', 'R001x33'}), frozenset({'R001x32', 'R001x34', 'R001x03'}), frozenset({'R001x01', 'R001x12'}), frozenset({'R001x32', 'R001x11', 'R001x01', 'R001x03'}), frozenset({'R001x22', 'R001x01', 'R001x02', 'R001x11', 'R001x34', 'R001x03'}), frozenset({'R001x22', 'R001x02'}), frozenset({'R001x22', 'R001x02', 'R001x99'}), frozenset({'R001x31', 'R001x03', 'R001x33'}), frozenset({'R001x36', 'R001x03'}), frozenset({'R001x37', 'R001x03', 'R001x33'}), frozenset({'R001x34', 'R001x11', 'R001x01', 'R001x03'}), frozenset({'R001x22', 'R001x01', 'R001x02', 'R001x32', 'R001x11', 'R001x03'}), frozenset({'R001x34', 'R001x01', 'R001x15', 'R001x03'}), frozenset({'R001x34', 'R001x03', 'R001x01', 'R001x12'})}
# Krippendorff's alpha: 0.29543346908442536

# %% [markdown]
# Based on α values of ~0.3, our annotation data should be **discarded** as unreliable.
